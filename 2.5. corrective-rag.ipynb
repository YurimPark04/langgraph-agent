# %%
from dotenv import load_dotenv


load_dotenv()
# Out:
# True

# %% [markdown]
# - web search를 할 수 있는 API 키가 필요하다

# %% [markdown]
# #### 기존 코드 불러오기

# %%
# 생성된 벡터스토어에 접근 -> 클래스만 바로 써야 함
from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma


embedding_function = OpenAIEmbeddings(model="text-embedding-3-large")

vector_store = Chroma(
    embedding_function=embedding_function,
    collection_name='income_tax_collection',
    persist_directory='./income_tax_collection' 
)

retriever = vector_store.as_retriever(search_kwargs={"k": 3})

# %%
# state 생성

from typing_extensions import TypedDict
from langchain_core.documents import Document
from langgraph.graph import StateGraph

class AgentState(TypedDict):
    query: str  

    # 웹 서치와 벡터스토어의 문서 구조가 다르기 때문에 List로 선언 
    context:list # vector store 대상으로 검색을 했는데, 여기에서는 추가적으로 web search로 얻은 자료가 이 context에 들어간다
    answer: str


graph_builder = StateGraph(AgentState)  # 빌더 생성

# %%
# retrieve
def retrieve(state:AgentState):
    query = state['query']  
    docs = retriever.invoke(query)  
    return {'context' : docs}

# %%
# llm과 prompt 분리 
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model='gpt-4o-mini')  # 가격을 위해서 mini로 대체

# %%
from langchain_classic import hub
from langchain_core.output_parsers import StrOutputParser


generate_prompt = hub.pull("rlm/rag-prompt") 

# generate
def generate(state: AgentState):
    context = state['context']
    query = state['query']
    rag_chain = generate_prompt | llm | StrOutputParser()
    response = rag_chain.invoke({'question': query, 'context':context})
    return {'answer' : response}

# %%
from langchain_classic import hub
from typing import Literal


doc_relevance_prompt = hub.pull("langchain-ai/rag-document-relevance")

def check_doc_relevance(state: AgentState) -> Literal['relevant', 'irrelevant']: 
    query = state['query']
    context = state['context']
    print(f'context == {context}') 
    doc_relevance_chain = doc_relevance_prompt | llm
    response = doc_relevance_chain.invoke({'question': query, 'documents':context})  
    print(f'doc relevance response == {response}') 

    if response['Score'] == 1:
        return 'relevant'
    
    return 'irrelevant'

# %% [markdown]
# #### 새로운 노드 생성

# %%
# rewrite

from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# 웹 검색에 용이하게 사용자의 질문 수정 -> 사전을 없애고, f-string 도 삭제해도 됨. 
rewrite_template = PromptTemplate.from_template("""
    사용자의 질문을 보고, 웹 검색에 용이하게 사용자의 질문을 수정해주세요
    질문 : {query}
    """
)

def rewrite(state: AgentState):
    query = state['query']
    rewrite_chain = rewrite_template | llm | StrOutputParser()  
    response = rewrite_chain.invoke({'query': query}) 
    
    print(f'rewrite question == {response}')  # 로그
    return {'query': response}

# %%
from langchain_tavily import TavilySearch
# from langchain_community.tools import TavilySearch   # cannot import 에러

tavily_search_tool = TavilySearch(
    max_results=3, 
    include_answer=True,
    include_raw_content=True,
    include_images=True,
    search_depth="advanced",
    
)

# tavily_search_tool.invoke({"query": "What happened at the last wimbledon"})

def web_search(state: AgentState):
    query = state['query']
    results = tavily_search_tool.invoke(query)  # List 형태 반환
    print(f'web_search question == {results}')  # 로그
    return {'context' : results}   # results가 List 형식

# %% [markdown]
# - vector store 과의 차이점? -> 구조가 다르다
#     - vector store : 'metadata', 'page_content' 키
#     - tavily : 'url', 'content' 키
# - AgentState 는 Document 형식이 아닌 List로 선언 (문서 구조가 다르기 때문)

# %% [markdown]
# #### rewrite를 활성화할 경우

# %%
graph_builder.add_node('retrieve', retrieve)
graph_builder.add_node('generate', generate)
# graph_builder.add_node('check_doc_relevance', check_doc_relevance)  # 노드에 들어가면 안됨 -> 앞 강의 코드 참고
graph_builder.add_node('rewrite', rewrite)
graph_builder.add_node('web_search', web_search)

# %%
# 엣지 추가

from langgraph.graph import START, END

graph_builder.add_edge(START, 'retrieve')
graph_builder.add_conditional_edges(
    'retrieve',
    check_doc_relevance,
    {
        'relevant' : 'generate',
        'irrelevant' : 'rewrite'
    }

)


graph_builder.add_edge('rewrite', 'web_search')
graph_builder.add_edge('web_search', 'generate')
graph_builder.add_edge('generate', END)

# %%
from IPython.display import Image, display

graph = graph_builder.compile()
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# #### initial_state

# %%
initial_state = {'query' : '연봉 5천만원 거주자의 소득세는 얼마인가요?'}
graph.invoke(initial_state) # score == 1
# Out:
# context == [Document(id='88ace334-edae-4d17-b6ba-850b2c9b99a5', metadata={'source': './docs/income_tax.txt'}, page_content='② 제70조제1항, 제70조의2에 따른 제74조에 따라 차례로 할 것이 제70조제1항제2호에 따르며 서류를 제출하여야 한다는 경우에는 기준소득 중 거주자 본인이 된다(분산)과 제70조제2와 제74조에 따른 제료 및 제대법을 포함한다. 단, 차별제표청정인 그 업체를 남겨 제출한 경우로 그에 대하여 아니하다.<개정 2013. 1. 1.>\n  ③ 제80조에 따른 수익과 관련의 경우에는 기초공제 중 거주자 본인이 된다(분산)과 그에 관한 적지사항을 분명히 한다.\n[전문개정 2009. 12. 31.]\n[제목개정 2014. 1. 1.]\n제54조의2(공동사업에 대한 소득공제 등 특례) 제51조의3 또는 「조세특례제한법」에 따른 소득공제를 적용하거나 제59조의2에 따른 세액감면을 적용하는 경우 제54조제3항에 따라 공동사업자의 소득에 합산과세되는 특별세액거래의 지출․납입․투자 등의 금액이 있을 경우 주된 공동사업자의 소득에 합산과세되는 소득금액에 합산되어 주된 공동사업자의 합산과세세액은 공동사업소득액 또는 공동사업창출세액을 계산할 때 소득공제 또는 세액공제를 받을 수 있다. \n[개정 2014. 1. 1.]\n[전문개정 2009. 12. 31.]\n[제목개정 2014. 1. 1.]\n제2절 세액의 계산 <개정 2009. 12. 31.>\n제1관 세율 <개정 2009. 12. 31.>\n제55조(세율) 거주자의 종합소득에 대한 소득세는 해당 연도의 종합소득과세표준에 다음의 세율을 적용하여 계산한 금액(이하 "종합소득과세표준세액"이라 한다)을 그 세액으로 한다. <개정 2014. 1. 1., 2016. 12. 20., 2017. 12. 19., 2020. 12. 29., 2022. 12. 31.>\n종합소득\n┌───────────────┐\n│ 과세표준의 6개 구간 │\n├───────────────┤\n│ 1,400만원 이하        │ 84만원  │\n│ 1,400만원 초과        │ 84만원 + (5,000만원을 초과하는 금액의 24%)  │\n│ 8,800만원 이하        │ 624만원 + (5,000만원을 초과하는 금액의 24%)  │\n│ 8,800만원 초과        │ 1,536만원 + (8,800만원을 초과하는 금액의 35%)  │\n│ 1.5억원 초과          │ 4,046만원 + (1,500만원을 초과하는 금액의 38%)  │\n│ 3억원 초과            │ 6,460만원 + (3억원을 초과하는 금액의 40%)  │\n│ 5억원 초과            │ 14,760만원 + (5억원을 초과하는 금액의 42%)  │\n│ 10억원 초과           │ 38,406만원 + (10억원을 초과하는 금액의 45%)  │\n└───────────────┘\n② 거주자의 퇴직소득에 대한 소득세는 다음 각 호의 순서에 따라 계산한 금액(이하 ‘퇴직소득 산출세액’이라 한다)으로 한다. <개정 2013. 1. 1., 2014. 12. 23.>\n1. 해당 과세기간의 퇴직소득과세표준 제1항의 세율을 적용하여 계산한 금액'), Document(id='5db2ab82-7abf-4612-8e35-e70504f4e855', metadata={'source': './docs/income_tax.txt'}, page_content='5년 이하: 30만원 → 납입연수\n5년 초과 10년 이하: 150만원 + 50만원 × (납입연수 - 5년)\n10년 초과 20년 이하: 400만원 + 80만원 × (납입연수 - 10년)\n20년 초과: 1,200만원 + 120만원 × (납입연수 - 20년)\n\n② 직장근로자 초과관세환급금을 분배하여 지급받는 경우 세액의 계산 방법 등 필요한 사항은 대통령령으로 정한다. \n<대통령 2014. 12. 23.>\n<전문개정 2009. 12. 31.>\n제64조(부동산매매업자에 대한 세액 계산의 특례)\n1) 대통령령으로 정하는 부동산매매업(이하 “부동산매매업”이라 한다)을 영위하는 거주자가 이하 “부동산매매업자”라 한다)로서 종합소득세법에 제104조제1항제1호(본항을 포함한다) 및 제103조 또는 같은 조 제7항 각 호의 어느 하나에 해당하는 자산의 매매자익(이하 “주택등매매차익”이라 한다)이 있는 자의 종합소득 산출세액은 다음 각 호의 세액 중 많은 것으로 한다. \n<개정 2014. 12. 23., 2017. 12. 19., 2020. 12. 29.>\n1. 종합소득 산출세액\n\n다음 각 목에 따른 세액의 합계액\n  가. 주택등매매차익에 따른 세율을 적용하여 산출한 세액의 합계액\n  나. 종합소득세법 제55조에 따라 주택등매매차익에 대한 개별세액을 공제한 금액을 과세표준으로 하고 이에 제55조에 따른 세율을 적용하여 산출세액'), Document(id='7d1fe2bc-d57d-4067-a42d-065188965264', metadata={'source': './docs/income_tax.txt'}, page_content='나. 단위표로액 합계액이 단위투표금의 100만원 이하이면서 적종한 개별투표 경우\n다. 제21조제3항제1호에 따른 복권 당첨금(복권당첨금을 복권 및 복권 기법법에 따라 분할하여 지급받는 경우에는 본항에 지급받는 금액의 합계액을 말한다) 또는 제21조제1항제14호에 따른 당첨금총액의 건별로 200만원 이하인 경우 \n라. 그 밖의 기타소득엑(제21조제1항제21호의 기타소득금액은 제외한다)이 건별로 5만원 이하인 경우 [전문개정 2009. 12. 31.]\n제2항 세액의 정수와 합산\n<개정 2009. 12. 31.>\n제86조(장수와 합금)\n남세지 관할 세무서장은 거주자 그 다음 각 호의 어느 하나에 해당하면 그 미달된 부분의 소득세를 "국세청장이"법에 따라 장수한다. <개정 2013. 1. 1.>')]
# doc relevance response == {'Score': 1, 'Explanation': 'The facts provided contain detailed information about the income tax regulations and rates for various income brackets, which are relevant to calculating the income tax for a resident with a yearly income of 50 million won (5천만원). The reference to specific income tax rates, exemptions, and tax calculation methods directly relates to the question of how much income tax a resident earning 5,000,000 won would owe. Therefore, the facts contain keywords and semantic meaning that make them relevant to the question, leading to a score of 1.'}
# {'query': '연봉 5천만원 거주자의 소득세는 얼마인가요?',
#  'context': [Document(id='88ace334-edae-4d17-b6ba-850b2c9b99a5', metadata={'source': './docs/income_tax.txt'}, page_content='② 제70조제1항, 제70조의2에 따른 제74조에 따라 차례로 할 것이 제70조제1항제2호에 따르며 서류를 제출하여야 한다는 경우에는 기준소득 중 거주자 본인이 된다(분산)과 제70조제2와 제74조에 따른 제료 및 제대법을 포함한다. 단, 차별제표청정인 그 업체를 남겨 제출한 경우로 그에 대하여 아니하다.<개정 2013. 1. 1.>\n  ③ 제80조에 따른 수익과 관련의 경우에는 기초공제 중 거주자 본인이 된다(분산)과 그에 관한 적지사항을 분명히 한다.\n[전문개정 2009. 12. 31.]\n[제목개정 2014. 1. 1.]\n제54조의2(공동사업에 대한 소득공제 등 특례) 제51조의3 또는 「조세특례제한법」에 따른 소득공제를 적용하거나 제59조의2에 따른 세액감면을 적용하는 경우 제54조제3항에 따라 공동사업자의 소득에 합산과세되는 특별세액거래의 지출․납입․투자 등의 금액이 있을 경우 주된 공동사업자의 소득에 합산과세되는 소득금액에 합산되어 주된 공동사업자의 합산과세세액은 공동사업소득액 또는 공동사업창출세액을 계산할 때 소득공제 또는 세액공제를 받을 수 있다. \n[개정 2014. 1. 1.]\n[전문개정 2009. 12. 31.]\n[제목개정 2014. 1. 1.]\n제2절 세액의 계산 <개정 2009. 12. 31.>\n제1관 세율 <개정 2009. 12. 31.>\n제55조(세율) 거주자의 종합소득에 대한 소득세는 해당 연도의 종합소득과세표준에 다음의 세율을 적용하여 계산한 금액(이하 "종합소득과세표준세액"이라 한다)을 그 세액으로 한다. <개정 2014. 1. 1., 2016. 12. 20., 2017. 12. 19., 2020. 12. 29., 2022. 12. 31.>\n종합소득\n┌───────────────┐\n│ 과세표준의 6개 구간 │\n├───────────────┤\n│ 1,400만원 이하        │ 84만원  │\n│ 1,400만원 초과        │ 84만원 + (5,000만원을 초과하는 금액의 24%)  │\n│ 8,800만원 이하        │ 624만원 + (5,000만원을 초과하는 금액의 24%)  │\n│ 8,800만원 초과        │ 1,536만원 + (8,800만원을 초과하는 금액의 35%)  │\n│ 1.5억원 초과          │ 4,046만원 + (1,500만원을 초과하는 금액의 38%)  │\n│ 3억원 초과            │ 6,460만원 + (3억원을 초과하는 금액의 40%)  │\n│ 5억원 초과            │ 14,760만원 + (5억원을 초과하는 금액의 42%)  │\n│ 10억원 초과           │ 38,406만원 + (10억원을 초과하는 금액의 45%)  │\n└───────────────┘\n② 거주자의 퇴직소득에 대한 소득세는 다음 각 호의 순서에 따라 계산한 금액(이하 ‘퇴직소득 산출세액’이라 한다)으로 한다. <개정 2013. 1. 1., 2014. 12. 23.>\n1. 해당 과세기간의 퇴직소득과세표준 제1항의 세율을 적용하여 계산한 금액'),
#   Document(id='5db2ab82-7abf-4612-8e35-e70504f4e855', metadata={'source': './docs/income_tax.txt'}, page_content='5년 이하: 30만원 → 납입연수\n5년 초과 10년 이하: 150만원 + 50만원 × (납입연수 - 5년)\n10년 초과 20년 이하: 400만원 + 80만원 × (납입연수 - 10년)\n20년 초과: 1,200만원 + 120만원 × (납입연수 - 20년)\n\n② 직장근로자 초과관세환급금을 분배하여 지급받는 경우 세액의 계산 방법 등 필요한 사항은 대통령령으로 정한다. \n<대통령 2014. 12. 23.>\n<전문개정 2009. 12. 31.>\n제64조(부동산매매업자에 대한 세액 계산의 특례)\n1) 대통령령으로 정하는 부동산매매업(이하 “부동산매매업”이라 한다)을 영위하는 거주자가 이하 “부동산매매업자”라 한다)로서 종합소득세법에 제104조제1항제1호(본항을 포함한다) 및 제103조 또는 같은 조 제7항 각 호의 어느 하나에 해당하는 자산의 매매자익(이하 “주택등매매차익”이라 한다)이 있는 자의 종합소득 산출세액은 다음 각 호의 세액 중 많은 것으로 한다. \n<개정 2014. 12. 23., 2017. 12. 19., 2020. 12. 29.>\n1. 종합소득 산출세액\n\n다음 각 목에 따른 세액의 합계액\n  가. 주택등매매차익에 따른 세율을 적용하여 산출한 세액의 합계액\n  나. 종합소득세법 제55조에 따라 주택등매매차익에 대한 개별세액을 공제한 금액을 과세표준으로 하고 이에 제55조에 따른 세율을 적용하여 산출세액'),
#   Document(id='7d1fe2bc-d57d-4067-a42d-065188965264', metadata={'source': './docs/income_tax.txt'}, page_content='나. 단위표로액 합계액이 단위투표금의 100만원 이하이면서 적종한 개별투표 경우\n다. 제21조제3항제1호에 따른 복권 당첨금(복권당첨금을 복권 및 복권 기법법에 따라 분할하여 지급받는 경우에는 본항에 지급받는 금액의 합계액을 말한다) 또는 제21조제1항제14호에 따른 당첨금총액의 건별로 200만원 이하인 경우 \n라. 그 밖의 기타소득엑(제21조제1항제21호의 기타소득금액은 제외한다)이 건별로 5만원 이하인 경우 [전문개정 2009. 12. 31.]\n제2항 세액의 정수와 합산\n<개정 2009. 12. 31.>\n제86조(장수와 합금)\n남세지 관할 세무서장은 거주자 그 다음 각 호의 어느 하나에 해당하면 그 미달된 부분의 소득세를 "국세청장이"법에 따라 장수한다. <개정 2013. 1. 1.>')],
#  'answer': '연봉 5천만원의 거주자에 대한 소득세는 최종적으로 624만원과 5천만원을 초과하는 금액의 24%를 더한 금액으로 계산됩니다. 따라서, 소득세는 624만원 + (0원을 초과하는 금액에 대해 24%)입니다. 구체적인 금액은 추가적인 과세표준에 따라 달라질 수 있습니다.'}

# %%
dummy_state = {'query' : '선유도역 맛집은?'}  # 엉뚱한 질문 넣어보기
graph.invoke(dummy_state)
# score == 0
# 답변을 웹 서치를 통해서 나옴

# query': '"선유도역 맛집 추천"' => 질문 수정한 것을 볼 수 있음
# Out:
# context == [Document(id='9687cef7-b202-4f20-a7c9-e0686d20eddf', metadata={'source': './docs/income_tax.txt'}, page_content='삭제<2020. 8. 18.>\n\n\n삭제<2014. 1. 1.>\n\n\n삭제<2014. 1. 1.>\n\n\n삭제<2014. 1. 1.>\n\n\n제104조3)에 따른 비사업용 토지\n\n\n| 양도소득 과세표준  | 세율               |\n|--------------------|--------------------|\n| 1,400만원 이하    | 16% 센트          |\n| 1,400만원 초과    | 24만원 초과(1,400만원 초과액 × 25패센트) |\n| 5,000만원 이하    | 5,000만원 초과(1,124만원 + (5,000만원 초과액 × 34패센트)) |\n| 8,800만원 이하    | 8,800만원 초과(2,416만원 + (8,800만원 초과액 × 45패센트)) |\n| 1억5,000만원 초과 | 5,206만원 초과(1억5,000만원 초과액 × 48패센트) |\n| 3억원 이하        | 1억2,406만원(3억원 초과액 × 50패센트) |\n| 5억원 이하        | 2억2,406만원(5억원 초과액 × 52패센트) |\n| 10억원 이하       | 4억8,406만원(10억원 초과액 × 55패센트) |\n| 10억원 초과       |                    |\n법제처                                      국가법령정보센터\n소득세법\n\n제94조제1항제4호 및 규칙에 따른 자산 중 제104조의3에 따른 비사업용 토지의 보유 현황을 고려하여 대통형으로 정하는 자산\n\n| 유형                         | 세율                |\n|------------------------------|---------------------|\n| 1,400만원 이하                | 16%           |\n| 1,400만원 초과               | 22,242만원 초과 시 25%셋트 |\n| 5,000만원 이하                | 1,124만원 초과 시 34%셋트 |\n| 5,000만원 초과               | 2,416만원 초과 시 45%셋트 |\n| 8,800만원 이하               | 1,000만원 초과 시 48%셋트 |\n| 1억 원이 초과                | 3%셋트          |\n| 3억원 이하                   | 19,406만원 초과 시 50%셋트 |\n| 5억원 초과                   | 29,406만원 초과 시 52%셋트 |\n| 10억원 초과                  | 48,406만원 초과 시 55%셋트 |\n\n\n미등기양도자산\n    양도소득과세표준의 100분의 70'), Document(id='47d4e8b0-29d3-481c-89e9-d1f36d2a70f5', metadata={'source': './docs/income_tax.txt'}, page_content='나. 장애인의 기능장애와 행동장애를 위한 발달재활서비스를 제공하는 대동법령으로 정하는 기관 다. 각유의 시설 또는 발명이 발생한 것으로 외부에서 있는 시설 또한 법인 \n라. 거주자(사업소득 포함)는 자는 제3조제4항제4호에 따라 지급된 대동법령으로 정하는 자는 포함한다. 다만 해당 제2기 고유기본과 기준법을 정하는 사람은 제1항이나 있는 자로 다음 각 호의 기초금액을 포함한 액에서 사업소득금을 계산할 때 필요금액이 산입되는 금액으로 변경의 경우에는 "제16조제3항제4호에" 기부금 세액공제에 "이익" 한정에는 적용하게 포함자세도 통상과세하는데 해당 사업소득이 있는 경우 사업소득에 대한 산출세액은 제외단계에서 정한다. 이 경우 특정의 기부금과 제2조의 기부금이 있을 경우에는 제1호의 기부금과 관련하여 시행할 때, 2013년 12월 31일 이전에 지급한 기부금은 2014년 1월 1일 이후에 게재되는 거주자의 이익 여부 소득공제를 하는 경우에는 해당 제2기에서 지급된 기부금은 더 이상 공제되지 않는다. \n\n\n\n20, 2018. 12. 31, 2020. 12. 29, 2022. 12. 31.'), Document(id='8adebb70-8624-4837-ba35-383d2ec488a1', metadata={'source': './docs/income_tax.txt'}, page_content='미등기양도자산\n    양도소득과세표준의 100분의 70\n\n\n제94조제1항제3호가목 및 규칙에 따른 자산\n   가. 소유주식의 비율· 시가총액 등을 고려하여 대통령령으로 정하는 대주주(이하 이 장에서 “대주주”라 한다)\n      양도소득 주식\n      1) 1년 미만 보유한 주식 등을 보아서 중소기업 외의 법인의 주식: 양도소득과세표준의 100분의 30\n      2) 1) 에 해당하지 아니하는 주식\n\n\n| 유형                         | 세율               |\n|------------------------------|---------------------|\n| 3억원 이하                   | 20%셋트           |\n| 3억원 초과                   | 6천만원 + (3천 원 초과) × 25%셋트 |\n나. 대주주가 아닌 자가 양도하는 주식\n   1) 중소기업의 주식: 양도소득과세표준의 100분의 10\n   2) 1) 에 해당하지 아니하는 주식: 양도소득과세표준의 100분의 20\n\n\n제94조제1항제3호다목에 따른 자산\n   가. 중소기업의 주식\n      양도소득과세표준의 100분의 10\n   나. 급박의 주식\n      양도소득과세표준의 100분의 20\n\n\n제94조제1항제7조에 따른 파생상품\n    양도소득과세표준의 100분의 20\n\n\n제94조제1항제6조에 따른 신탁 수익권\n\n\n양도소득과세표준\n제목\n소득세법\n3억원 이하\n\n20% 적용\n\n3억원 초과\n\n\n6,000만원 + (3억원 초과액 × 25%)\n\n\n상속받은 자산은 피상속인이 그 자산을 취득한 날')]
# doc relevance response == {'Score': 0, 'Explanation': 'The provided FACTS discuss complex tax regulations, rates, and legislative references related to income tax and asset transfer taxation. There is no mention of restaurants, cafes, or any food-related topics, which makes these facts completely unrelated to the question about 맛집 (restaurants) at 선유도역 (Seonyudo Station). Therefore, I assign a score of 0 for irrelevance.'}
# rewrite question == 수정된 질문: "선유도역 근처 맛집 추천"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 2
#       1 dummy_state = {'query' : '선유도역 맛집은?'}  # 엉뚱한 질문 넣어보기
# ----> 2 graph.invoke(dummy_state)
#       3 # score == 0
#       4 # 답변을 웹 서치를 통해서 나옴
#       5
#       6 # query': '"선유도역 맛집 추천"' => 질문 수정한 것을 볼 수 있음
#
# File d:\work\project\workspace\AI\langgraph-agent\langgraphvenv\Lib\site-packages\langgraph\pregel\main.py:3290, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, version, **kwargs)
#    3287             chunks.append(chunk)
#    3288 else:
#    3289     # v1: collect interrupts from updates stream
# -> 3290     for chunk in self.stream(
#    3291         input,
#    3292         config,
#    3293         context=context,
#    3294         stream_mode=(
#    3295             ["updates", "values"] if stream_mode == "values" else stream_mode
#    3296         ),
#    3297         print_mode=print_mode,
#    3298         output_keys=output_keys,
#    3299         interrupt_before=interrupt_before,
#    3300         interrupt_after=interrupt_after,
#    3301         durability=durability,
#    3302         **kwargs,
#    3303     ):
#    3304         if stream_mode == "values":
#    3305             if len(chunk) == 2:
#
# File d:\work\project\workspace\AI\langgraph-agent\langgraphvenv\Lib\site-packages\langgraph\pregel\main.py:2724, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, version, **kwargs)
#    2722 for task in loop.match_cached_writes():
#    2723     loop.output_writes(task.id, task.writes, cached=True)
# -> 2724 for _ in runner.tick(
#    2725     [t for t in loop.tasks.values() if not t.writes],
#    2726     timeout=self.step_timeout,
#    2727     get_waiter=get_waiter,
#    2728     schedule_task=loop.accept_push,
#    2729 ):
#    2730     # emit output
#    2731     yield from _output(
#    2732         stream_mode,
#    2733         print_mode,
#    (...)   2739         _state_mapper,
#    2740     )
#    2741 loop.after_tick()
#
# File d:\work\project\workspace\AI\langgraph-agent\langgraphvenv\Lib\site-packages\langgraph\pregel\_runner.py:167, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     165 t = tasks[0]
#     166 try:
# --> 167     run_with_retry(
#     168         t,
#     169         retry_policy,
#     170         configurable={
#     171             CONFIG_KEY_CALL: partial(
#     172                 _call,
#     173                 weakref.ref(t),
#     174                 retry_policy=retry_policy,
#     175                 futures=weakref.ref(futures),
#     176                 schedule_task=schedule_task,
#     177                 submit=self.submit,
#     178             ),
#     179         },
#     180     )
#     181     self.commit(t, None)
#     182 except Exception as exc:
#
# File d:\work\project\workspace\AI\langgraph-agent\langgraphvenv\Lib\site-packages\langgraph\pregel\_retry.py:71, in run_with_retry(task, retry_policy, configurable)
#      69     task.writes.clear()
#      70     # run the task
# ---> 71     return task.proc.invoke(task.input, config)
#      72 except ParentCommand as exc:
#      73     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File d:\work\project\workspace\AI\langgraph-agent\langgraphvenv\Lib\site-packages\langgraph\_internal\_runnable.py:656, in RunnableSeq.invoke(self, input, config, **kwargs)
#     654     # run in context
#     655     with set_config_context(config, run) as context:
# --> 656         input = context.run(step.invoke, input, config, **kwargs)
#     657 else:
#     658     input = step.invoke(input, config)
#
# File d:\work\project\workspace\AI\langgraph-agent\langgraphvenv\Lib\site-packages\langgraph\_internal\_runnable.py:400, in RunnableCallable.invoke(self, input, config, **kwargs)
#     398         run_manager.on_chain_end(ret)
#     399 else:
# --> 400     ret = self.func(*args, **kwargs)
#     401 if self.recurse and isinstance(ret, Runnable):
#     402     return ret.invoke(input, config)
#
# Cell In[9], line 17, in web_search(state)
#      15 def web_search(state: AgentState):
#      16     query = state['query']
# ---> 17     results = tavily_search_tool.invoke(query)  # List 형태 반환
#      18     print(f'web_search question == {results}')  # 로그
#      19     return {'context' : results}
#
# File d:\work\project\workspace\AI\langgraph-agent\langgraphvenv\Lib\site-packages\langchain_core\tools\base.py:642, in BaseTool.invoke(self, input, config, **kwargs)
#     634 @override
#     635 def invoke(
#     636     self,
#    (...)    639     **kwargs: Any,
#     640 ) -> Any:
#     641     tool_input, kwargs = _prep_run_args(input, config, **kwargs)
# --> 642     return self.run(tool_input, **kwargs)
#
# File d:\work\project\workspace\AI\langgraph-agent\langgraphvenv\Lib\site-packages\langchain_core\tools\base.py:1001, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#     999 if error_to_raise:
#    1000     run_manager.on_tool_error(error_to_raise, tool_call_id=tool_call_id)
# -> 1001     raise error_to_raise
#    1002 output = _format_output(content, artifact, tool_call_id, self.name, status)
#    1003 run_manager.on_tool_end(output, color=color, name=self.name, **kwargs)
#
# File d:\work\project\workspace\AI\langgraph-agent\langgraphvenv\Lib\site-packages\langchain_core\tools\base.py:967, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#     965     if config_param := _get_runnable_config_param(self._run):
#     966         tool_kwargs |= {config_param: config}
# --> 967     response = context.run(self._run, *tool_args, **tool_kwargs)
#     968 if self.response_format == "content_and_artifact":
#     969     msg = (
#     970         "Since response_format='content_and_artifact' "
#     971         "a two-tuple of the message content and raw tool output is "
#     972         f"expected. Instead, generated response is of type: "
#     973         f"{type(response)}."
#     974     )
#
# File d:\work\project\workspace\AI\langgraph-agent\langgraphvenv\Lib\site-packages\langchain_tavily\tavily_search.py:378, in TavilySearch._run(self, query, include_domains, exclude_domains, search_depth, include_images, time_range, topic, start_date, end_date, run_manager, **kwargs)
#     373         raise ValueError(
#     374             f"The parameter '{param}' can only be set during instantiation, not during invocation. Please set it when creating the TavilySearch instance."
#     375         )
#     377 # Execute search with parameters directly
# --> 378 raw_results = self.api_wrapper.raw_results(
#     379     query=query,
#     380     include_domains=self.include_domains
#     381     if self.include_domains
#     382     else include_domains,
#     383     exclude_domains=self.exclude_domains
#     384     if self.exclude_domains
#     385     else exclude_domains,
#     386     search_depth=self.search_depth if self.search_depth else search_depth,
#     387     include_images=self.include_images
#     388     if self.include_images
#     389     else include_images,
#     390     time_range=self.time_range if self.time_range else time_range,
#     391     topic=self.topic if self.topic else topic,
#     392     include_favicon=self.include_favicon,
#     393     country=self.country,
#     394     max_results=self.max_results,
#     395     include_answer=self.include_answer,
#     396     include_raw_content=self.include_raw_content,
#     397     include_image_descriptions=self.include_image_descriptions,
#     398     auto_parameters=self.auto_parameters,
#     399     start_date=start_date,
#     400     end_date=end_date,
#     401     include_usage=self.include_usage,
#     402     **kwargs,
#     403 )
#     405 # Check if results are empty and raise a specific exception
#     406 if not raw_results.get("results", []):
#
# File d:\work\project\workspace\AI\langgraph-agent\langgraphvenv\Lib\site-packages\langchain_tavily\_utilities.py:92, in TavilySearchAPIWrapper.raw_results(self, query, max_results, search_depth, include_domains, exclude_domains, include_answer, include_raw_content, include_images, include_image_descriptions, include_favicon, topic, time_range, country, auto_parameters, start_date, end_date, include_usage, **kwargs)
#      86 headers = {
#      87     "Authorization": f"Bearer {self.tavily_api_key.get_secret_value()}",
#      88     "Content-Type": "application/json",
#      89     "X-Client-Source": "langchain-tavily",
#      90 }
#      91 base_url = self.api_base_url or TAVILY_API_URL
# ---> 92 response = requests.post(
#      93     # type: ignore
#      94     f"{base_url}/search",
#      95     json=params,
#      96     headers=headers,
#      97 )
#      98 if response.status_code != 200:
#      99     detail = response.json().get("detail", {})
#
# File d:\work\project\workspace\AI\langgraph-agent\langgraphvenv\Lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)    112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File d:\work\project\workspace\AI\langgraph-agent\langgraphvenv\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File d:\work\project\workspace\AI\langgraph-agent\langgraphvenv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File d:\work\project\workspace\AI\langgraph-agent\langgraphvenv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File d:\work\project\workspace\AI\langgraph-agent\langgraphvenv\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File d:\work\project\workspace\AI\langgraph-agent\langgraphvenv\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File d:\work\project\workspace\AI\langgraph-agent\langgraphvenv\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File d:\work\project\workspace\AI\langgraph-agent\langgraphvenv\Lib\site-packages\urllib3\connection.py:571, in HTTPConnection.getresponse(self)
#     568 _shutdown = getattr(self.sock, "shutdown", None)
#     570 # Get the response from http.client.HTTPConnection
# --> 571 httplib_response = super().getresponse()
#     573 try:
#     574     assert_header_parsing(httplib_response.msg)
#
# File ~\anaconda3\Lib\http\client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File ~\anaconda3\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~\anaconda3\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~\anaconda3\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File ~\anaconda3\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# #### rewrite를 비활성화하는 경우
# - 사용자의 질문을 수정하는 rewrite 과정이 필요한지?
#     - 공손한 표현을 쓰면 더 잘 나온다는 말도 있지만, 크게 의미 X

# %%
# rewrite 노드를 제거하고, 엣지 연결 수정

graph_builder.add_node('retrieve', retrieve)
graph_builder.add_node('generate', generate)
# graph_builder.add_node('rewrite', rewrite)
graph_builder.add_node('web_search', web_search)

# %%
# 엣지 추가
from langgraph.graph import START, END

graph_builder.add_edge(START, 'retrieve')
graph_builder.add_conditional_edges(
    'retrieve',
    check_doc_relevance,
    {
        'relevant' : 'generate',
        'irrelevant' : 'web_search'  # irrelevant라면, rewrite 가 아니라 web_search로 바로 가도록
    }

)

# graph_builder.add_edge('rewrite', 'web_search')
graph_builder.add_edge('web_search', 'generate')
graph_builder.add_edge('generate', END)

# %%
from IPython.display import Image, display

graph = graph_builder.compile()
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
# 직전에 돌렸던 것보다 빨리 답변 생성되는 이유?
# 자체적으로 업데이트 해서 비슷한 질문이 들어오면 cache 한 답변을 바로 주는 식으로 OPENAI API가 업데이트하기 때문

# %%
dummy_state = {'query' : '선유도역 맛집은?'}  # 엉뚱한 질문 넣어보기
graph.invoke(dummy_state)
# score == 0

# query': 질문 수정을 하지 않아도, 나오는 답변은 위와 비슷하다.
# Out:
# context == [Document(id='9687cef7-b202-4f20-a7c9-e0686d20eddf', metadata={'source': './docs/income_tax.txt'}, page_content='삭제<2020. 8. 18.>\n\n\n삭제<2014. 1. 1.>\n\n\n삭제<2014. 1. 1.>\n\n\n삭제<2014. 1. 1.>\n\n\n제104조3)에 따른 비사업용 토지\n\n\n| 양도소득 과세표준  | 세율               |\n|--------------------|--------------------|\n| 1,400만원 이하    | 16% 센트          |\n| 1,400만원 초과    | 24만원 초과(1,400만원 초과액 × 25패센트) |\n| 5,000만원 이하    | 5,000만원 초과(1,124만원 + (5,000만원 초과액 × 34패센트)) |\n| 8,800만원 이하    | 8,800만원 초과(2,416만원 + (8,800만원 초과액 × 45패센트)) |\n| 1억5,000만원 초과 | 5,206만원 초과(1억5,000만원 초과액 × 48패센트) |\n| 3억원 이하        | 1억2,406만원(3억원 초과액 × 50패센트) |\n| 5억원 이하        | 2억2,406만원(5억원 초과액 × 52패센트) |\n| 10억원 이하       | 4억8,406만원(10억원 초과액 × 55패센트) |\n| 10억원 초과       |                    |\n법제처                                      국가법령정보센터\n소득세법\n\n제94조제1항제4호 및 규칙에 따른 자산 중 제104조의3에 따른 비사업용 토지의 보유 현황을 고려하여 대통형으로 정하는 자산\n\n| 유형                         | 세율                |\n|------------------------------|---------------------|\n| 1,400만원 이하                | 16%           |\n| 1,400만원 초과               | 22,242만원 초과 시 25%셋트 |\n| 5,000만원 이하                | 1,124만원 초과 시 34%셋트 |\n| 5,000만원 초과               | 2,416만원 초과 시 45%셋트 |\n| 8,800만원 이하               | 1,000만원 초과 시 48%셋트 |\n| 1억 원이 초과                | 3%셋트          |\n| 3억원 이하                   | 19,406만원 초과 시 50%셋트 |\n| 5억원 초과                   | 29,406만원 초과 시 52%셋트 |\n| 10억원 초과                  | 48,406만원 초과 시 55%셋트 |\n\n\n미등기양도자산\n    양도소득과세표준의 100분의 70'), Document(id='47d4e8b0-29d3-481c-89e9-d1f36d2a70f5', metadata={'source': './docs/income_tax.txt'}, page_content='나. 장애인의 기능장애와 행동장애를 위한 발달재활서비스를 제공하는 대동법령으로 정하는 기관 다. 각유의 시설 또는 발명이 발생한 것으로 외부에서 있는 시설 또한 법인 \n라. 거주자(사업소득 포함)는 자는 제3조제4항제4호에 따라 지급된 대동법령으로 정하는 자는 포함한다. 다만 해당 제2기 고유기본과 기준법을 정하는 사람은 제1항이나 있는 자로 다음 각 호의 기초금액을 포함한 액에서 사업소득금을 계산할 때 필요금액이 산입되는 금액으로 변경의 경우에는 "제16조제3항제4호에" 기부금 세액공제에 "이익" 한정에는 적용하게 포함자세도 통상과세하는데 해당 사업소득이 있는 경우 사업소득에 대한 산출세액은 제외단계에서 정한다. 이 경우 특정의 기부금과 제2조의 기부금이 있을 경우에는 제1호의 기부금과 관련하여 시행할 때, 2013년 12월 31일 이전에 지급한 기부금은 2014년 1월 1일 이후에 게재되는 거주자의 이익 여부 소득공제를 하는 경우에는 해당 제2기에서 지급된 기부금은 더 이상 공제되지 않는다. \n\n\n\n20, 2018. 12. 31, 2020. 12. 29, 2022. 12. 31.'), Document(id='8adebb70-8624-4837-ba35-383d2ec488a1', metadata={'source': './docs/income_tax.txt'}, page_content='미등기양도자산\n    양도소득과세표준의 100분의 70\n\n\n제94조제1항제3호가목 및 규칙에 따른 자산\n   가. 소유주식의 비율· 시가총액 등을 고려하여 대통령령으로 정하는 대주주(이하 이 장에서 “대주주”라 한다)\n      양도소득 주식\n      1) 1년 미만 보유한 주식 등을 보아서 중소기업 외의 법인의 주식: 양도소득과세표준의 100분의 30\n      2) 1) 에 해당하지 아니하는 주식\n\n\n| 유형                         | 세율               |\n|------------------------------|---------------------|\n| 3억원 이하                   | 20%셋트           |\n| 3억원 초과                   | 6천만원 + (3천 원 초과) × 25%셋트 |\n나. 대주주가 아닌 자가 양도하는 주식\n   1) 중소기업의 주식: 양도소득과세표준의 100분의 10\n   2) 1) 에 해당하지 아니하는 주식: 양도소득과세표준의 100분의 20\n\n\n제94조제1항제3호다목에 따른 자산\n   가. 중소기업의 주식\n      양도소득과세표준의 100분의 10\n   나. 급박의 주식\n      양도소득과세표준의 100분의 20\n\n\n제94조제1항제7조에 따른 파생상품\n    양도소득과세표준의 100분의 20\n\n\n제94조제1항제6조에 따른 신탁 수익권\n\n\n양도소득과세표준\n제목\n소득세법\n3억원 이하\n\n20% 적용\n\n3억원 초과\n\n\n6,000만원 + (3억원 초과액 × 25%)\n\n\n상속받은 자산은 피상속인이 그 자산을 취득한 날')]
# doc relevance response == {'Score': 0, 'Explanation': 'The question asks for information specifically about restaurants (맛집) around Seonyudo Station (선유도역). The provided facts, however, focus entirely on legal and tax-related content concerning income tax and capital gains related to land and property, without any mention of dining, restaurants, or specific locations relevant to the query. Since none of the facts contain keywords or semantic meanings that relate to dining establishments, the score is 0.'}
# web_search question == {'query': '선유도역 맛집은?', 'follow_up_questions': None, 'answer': '선유도역 주변 맛집으로 또순이네 쌀국수, 샤브올데이 무한리필, 호운양꼬치 양꼬치, 멕시코식당 타코가 있습니다. 각 가게는 다양한 메뉴와 편의를 제공합니다.', 'images': ['https://cdn.gpkorea.com/news/photo/202002/61918_151357_5924.jpg', 'https://mblogthumb-phinf.pstatic.net/MjAyNDA0MjVfNzQg/MDAxNzEzOTk5OTIzNDEy.aQ2-3h6gaYp2W45967dldNdFeUrWgu8HFBGwdQwAgHMg.i3H8mLzHZLFIXWfSh_QEM-0wm6RL5_o92dYnxmaNkNEg.JPEG/IMG_4340.JPG?type=w800', 'https://blogthumb.pstatic.net/MjAyNDAxMjVfMjU4/MDAxNzA2MTg5NzgxMjEz.xbfURIWe6-zJgwHiNxXGopfvYHzdb8hE3ccxujV-F_og.1GrGvsHzhhI_0xA73A_uZa1PC_OTqaBu5-cv9Wttpfgg.JPEG.p4251hpr/IMG_7100.jpg?type=w2', 'https://blogthumb.pstatic.net/MjAyMjA5MjNfOTcg/MDAxNjYzOTExMDgyMjg0.MtYpunnFlrmGWRNhKkV0_8ip9g8O_gKVR2TbBktyENYg.rm1K1uTN0b_TTkHbRqCCKJKkxrNvQLN12w2aWK1WvdEg.JPEG.xyzzinny/IMG_6558.jpg?type=w2', 'https://blogthumb.pstatic.net/MjAyMjExMjhfNCAg/MDAxNjY5NTY4MjkyMzg1.eSqP8eUxpll_FqqGnxvtgmvLlqmcOZ__7wFsXw_cv0Eg.4jLCgw8jX1UNXlH3VHWlzTfPKoRDXQh2UIw-Obd0lRcg.JPEG.kyr1669/IMG_7993.jpg?type=w2'], 'results': [{'url': 'https://anadasia88.tistory.com/24', 'title': '9호선 선유도역 주변 맛집 - anadasia88 님의 블로그', 'content': '# anadasia88 님의 블로그\n\n카테고리 없음\n\n# 9호선 선유도역 주변 맛집\n\n눈이 내리는 3월의 봄\n\n3월 18일 화요일 점심시간이었습니다.\n\n바람도 불고 눈발도 날리는 날씨였지만\n\n당산에서 걸어서 선유도역까지 가보기로 했습니다.\n\n국수를 유난히 좋아하는 대표님과 함께\n\n뚜벅이로 운동 삼아 식당을 찾았어요.\n\n메뉴는 온면으로 2개 주문했고\n\n미리 키오스크로 결제를 마쳤습니다.\n\n이곳은\n\n‘나눔’까지 실천하는 착한 식당이라고 해서\n\n기대감이 더 커졌습니다.\n\n위치는 선유도역 2번 출구에서 도보 1분 거리\n\n주택가 골목 안쪽에 자리하고 있었습니다.\n\n도착하니 우리 팀 앞에 이미 2팀이 있었고\n\n대기시간은 약 20~30분 정도 걸렸습니다.\n\n날씨가 추웠지만 기다릴 만한 가치가 있을까 하는\n\n기대 반, 궁금함 반으로 줄을 섰습니다.\n\n자리에 앉자 1인용 쟁반에\n\n온면이 담겨 나왔습니다.\n\n고기 양이 꽤 많아 보였고\n\n국물 향이 고소하게 올라왔습니다.\n\n저는 칼국수라고 생각하고 왔는데\n\n실제로는 쌀국수였습니다.\n\n가격은 12,000원으로 쌀국수치고는 조금 비싼 편이었지만\n\n고기와 육수 맛이 상당히 좋았습니다.\n\n특히 육수는 인위적인 조미료 맛이 아니라\n\n재료 본연의 깊고 깔끔한 맛이 느껴졌습니다.\n\n마치 집에서 정성껏 끓여낸 것 같은 건강한 맛이었어요.\n\n양이 조금 부족하다면 리필도 가능했습니다.\n\n밥이나 국수를 더 달라고 하면 기꺼이 챙겨주는 모습이 참 인상적이었어요.\n\n사장님과 직원분들이 젊은 남성 세 분이었는데\n\n손이 빠르고 호흡이 척척 맞아 보였습니다.\n\n다만 [...] \\ 단축키는 한글/영문 대소문자로 이용 가능하며, 티스토리 기본 도메인에서만 동작합니다.', 'score': 0.9995859, 'raw_content': '# [anadasia88 님의 블로그](https://anadasia88.tistory.com/)\n\n\n\n---\n\n카테고리 없음\n\n# 9호선 선유도역 주변 맛집\n\n눈이 내리는 3월의 봄\n\n3월 18일 화요일 점심시간이었습니다.\n\n바람도 불고 눈발도 날리는 날씨였지만\n\n당산에서 걸어서 선유도역까지 가보기로 했습니다.\n\n국수를 유난히 좋아하는 대표님과 함께\n\n뚜벅이로 운동 삼아 식당을 찾았어요.\n\n메뉴는 온면으로 2개 주문했고\n\n미리 키오스크로 결제를 마쳤습니다.\n\n이곳은\n\n‘나눔’까지 실천하는 착한 식당이라고 해서\n\n기대감이 더 커졌습니다.\n\n위치는 선유도역 2번 출구에서 도보 1분 거리\n\n주택가 골목 안쪽에 자리하고 있었습니다.\n\n도착하니 우리 팀 앞에 이미 2팀이 있었고\n\n대기시간은 약 20~30분 정도 걸렸습니다.\n\n날씨가 추웠지만 기다릴 만한 가치가 있을까 하는\n\n기대 반, 궁금함 반으로 줄을 섰습니다.\n\n자리에 앉자 1인용 쟁반에\n\n온면이 담겨 나왔습니다.\n\n고기 양이 꽤 많아 보였고\n\n국물 향이 고소하게 올라왔습니다.\n\n저는 칼국수라고 생각하고 왔는데\n\n실제로는 쌀국수였습니다.\n\n가격은 12,000원으로 쌀국수치고는 조금 비싼 편이었지만\n\n고기와 육수 맛이 상당히 좋았습니다.\n\n특히 육수는 인위적인 조미료 맛이 아니라\n\n재료 본연의 깊고 깔끔한 맛이 느껴졌습니다.\n\n마치 집에서 정성껏 끓여낸 것 같은 건강한 맛이었어요.\n\n양이 조금 부족하다면 리필도 가능했습니다.\n\n밥이나 국수를 더 달라고 하면 기꺼이 챙겨주는 모습이 참 인상적이었어요.\n\n사장님과 직원분들이 젊은 남성 세 분이었는데\n\n손이 빠르고 호흡이 척척 맞아 보였습니다.\n\n다만\n\n내부가 상당히 좁은 편이라 식사 시간에는 대기가 불가피할 것 같습니다.\n\n혹시 방문할 계획이 있다면 점심·저녁 피크 시간을 피해 가는 게 좋겠습니다.\n\n테이블은 길게 일자형으로 배치되어 있어 혼밥하기에도 아주 편한 구조였습니다.\n\n추운 날씨 속에서도 따끈한 국물과 푸짐한 고기를 즐기며  \n걷고 기다린 시간이 전혀 아깝지 않았던 한 끼였습니다.\n\n함께한 사람과 나눈 대화\n\n그리고 마음까지 따뜻해진 맛이 오래 기억에 남을 것 같습니다.\n\n[anadasia88 님의 블로그](https://anadasia88.tistory.com)[소소한 일상 속에서 발견하는 작은 행복, 그리고 그 순간들을 기록하는 공간입니다.\n길 위에서 마주한 풍경, 잔잔한 음악이 흐르는 카페, 그리고 일상 속에서 찾은 특별한 순간들.\n이곳에서 나만의 감성을 담아 기록합니다.](https://anadasia88.tistory.com)\n\n댓글0\n\n---\n\n## 티스토리툴바\n\n## 개인정보\n\n* [티스토리 홈](https://www.tistory.com)\n* [포럼](https://www.tistory.com/forum)\n* [로그인](#)\n\n\n\n\n\n## 단축키\n\n### 내 블로그\n\n|  |  |\n| --- | --- |\n| 내 블로그 - 관리자 홈 전환 | `Q` |\n| 새 글 쓰기 | `W` |\n\n### 블로그 게시글\n\n|  |  |\n| --- | --- |\n| 글 수정 (권한 있는 경우) | `E` |\n| 댓글 영역으로 이동 | `C` |\n\n### 모든 영역\n\n|  |  |\n| --- | --- |\n| 이 페이지의 URL 복사 | `S` |\n| 맨 위로 이동 | `T` |\n| 티스토리 홈 이동 | `H` |\n| 단축키 안내 | `Shift` + `/`  `⇧` + `/` |\n\n\\* 단축키는 한글/영문 대소문자로 이용 가능하며, 티스토리 기본 도메인에서만 동작합니다.'}, {'url': 'https://www ...
# {'query': '선유도역 맛집은?',
#  'context': {'query': '선유도역 맛집은?',
#   'follow_up_questions': None,
#   'answer': '선유도역 주변 맛집으로 또순이네 쌀국수, 샤브올데이 무한리필, 호운양꼬치 양꼬치, 멕시코식당 타코가 있습니다. 각 가게는 다양한 메뉴와 편의를 제공합니다.',
#   'images': ['https://cdn.gpkorea.com/news/photo/202002/61918_151357_5924.jpg',
#    'https://mblogthumb-phinf.pstatic.net/MjAyNDA0MjVfNzQg/MDAxNzEzOTk5OTIzNDEy.aQ2-3h6gaYp2W45967dldNdFeUrWgu8HFBGwdQwAgHMg.i3H8mLzHZLFIXWfSh_QEM-0wm6RL5_o92dYnxmaNkNEg.JPEG/IMG_4340.JPG?type=w800',
#    'https://blogthumb.pstatic.net/MjAyNDAxMjVfMjU4/MDAxNzA2MTg5NzgxMjEz.xbfURIWe6-zJgwHiNxXGopfvYHzdb8hE3ccxujV-F_og.1GrGvsHzhhI_0xA73A_uZa1PC_OTqaBu5-cv9Wttpfgg.JPEG.p4251hpr/IMG_7100.jpg?type=w2',
#    'https://blogthumb.pstatic.net/MjAyMjA5MjNfOTcg/MDAxNjYzOTExMDgyMjg0.MtYpunnFlrmGWRNhKkV0_8ip9g8O_gKVR2TbBktyENYg.rm1K1uTN0b_TTkHbRqCCKJKkxrNvQLN12w2aWK1WvdEg.JPEG.xyzzinny/IMG_6558.jpg?type=w2',
#    'https://blogthumb.pstatic.net/MjAyMjExMjhfNCAg/MDAxNjY5NTY4MjkyMzg1.eSqP8eUxpll_FqqGnxvtgmvLlqmcOZ__7wFsXw_cv0Eg.4jLCgw8jX1UNXlH3VHWlzTfPKoRDXQh2UIw-Obd0lRcg.JPEG.kyr1669/IMG_7993.jpg?type=w2'],
#   'results': [{'url': 'https://anadasia88.tistory.com/24',
#     'title': '9호선 선유도역 주변 맛집 - anadasia88 님의 블로그',
#     'content': '# anadasia88 님의 블로그\n\n카테고리 없음\n\n# 9호선 선유도역 주변 맛집\n\n눈이 내리는 3월의 봄\n\n3월 18일 화요일 점심시간이었습니다.\n\n바람도 불고 눈발도 날리는 날씨였지만\n\n당산에서 걸어서 선유도역까지 가보기로 했습니다.\n\n국수를 유난히 좋아하는 대표님과 함께\n\n뚜벅이로 운동 삼아 식당을 찾았어요.\n\n메뉴는 온면으로 2개 주문했고\n\n미리 키오스크로 결제를 마쳤습니다.\n\n이곳은\n\n‘나눔’까지 실천하는 착한 식당이라고 해서\n\n기대감이 더 커졌습니다.\n\n위치는 선유도역 2번 출구에서 도보 1분 거리\n\n주택가 골목 안쪽에 자리하고 있었습니다.\n\n도착하니 우리 팀 앞에 이미 2팀이 있었고\n\n대기시간은 약 20~30분 정도 걸렸습니다.\n\n날씨가 추웠지만 기다릴 만한 가치가 있을까 하는\n\n기대 반, 궁금함 반으로 줄을 섰습니다.\n\n자리에 앉자 1인용 쟁반에\n\n온면이 담겨 나왔습니다.\n\n고기 양이 꽤 많아 보였고\n\n국물 향이 고소하게 올라왔습니다.\n\n저는 칼국수라고 생각하고 왔는데\n\n실제로는 쌀국수였습니다.\n\n가격은 12,000원으로 쌀국수치고는 조금 비싼 편이었지만\n\n고기와 육수 맛이 상당히 좋았습니다.\n\n특히 육수는 인위적인 조미료 맛이 아니라\n\n재료 본연의 깊고 깔끔한 맛이 느껴졌습니다.\n\n마치 집에서 정성껏 끓여낸 것 같은 건강한 맛이었어요.\n\n양이 조금 부족하다면 리필도 가능했습니다.\n\n밥이나 국수를 더 달라고 하면 기꺼이 챙겨주는 모습이 참 인상적이었어요.\n\n사장님과 직원분들이 젊은 남성 세 분이었는데\n\n손이 빠르고 호흡이 척척 맞아 보였습니다.\n\n다만 [...] \\ 단축키는 한글/영문 대소문자로 이용 가능하며, 티스토리 기본 도메인에서만 동작합니다.',
#     'score': 0.9995859,
#     'raw_content': '# [anadasia88 님의 블로그](https://anadasia88.tistory.com/)\n\n\n\n---\n\n카테고리 없음\n\n# 9호선 선유도역 주변 맛집\n\n눈이 내리는 3월의 봄\n\n3월 18일 화요일 점심시간이었습니다.\n\n바람도 불고 눈발도 날리는 날씨였지만\n\n당산에서 걸어서 선유도역까지 가보기로 했습니다.\n\n국수를 유난히 좋아하는 대표님과 함께\n\n뚜벅이로 운동 삼아 식당을 찾았어요.\n\n메뉴는 온면으로 2개 주문했고\n\n미리 키오스크로 결제를 마쳤습니다.\n\n이곳은\n\n‘나눔’까지 실천하는 착한 식당이라고 해서\n\n기대감이 더 커졌습니다.\n\n위치는 선유도역 2번 출구에서 도보 1분 거리\n\n주택가 골목 안쪽에 자리하고 있었습니다.\n\n도착하니 우리 팀 앞에 이미 2팀이 있었고\n\n대기시간은 약 20~30분 정도 걸렸습니다.\n\n날씨가 추웠지만 기다릴 만한 가치가 있을까 하는\n\n기대 반, 궁금함 반으로 줄을 섰습니다.\n\n자리에 앉자 1인용 쟁반에\n\n온면이 담겨 나왔습니다.\n\n고기 양이 꽤 많아 보였고\n\n국물 향이 고소하게 올라왔습니다.\n\n저는 칼국수라고 생각하고 왔는데\n\n실제로는 쌀국수였습니다.\n\n가격은 12,000원으로 쌀국수치고는 조금 비싼 편이었지만\n\n고기와 육수 맛이 상당히 좋았습니다.\n\n특히 육수는 인위적인 조미료 맛이 아니라\n\n재료 본연의 깊고 깔끔한 맛이 느껴졌습니다.\n\n마치 집에서 정성껏 끓여낸 것 같은 건강한 맛이었어요.\n\n양이 조금 부족하다면 리필도 가능했습니다.\n\n밥이나 국수를 더 달라고 하면 기꺼이 챙겨주는 모습이 참 인상적이었어요.\n\n사장님과 직원분들이 젊은 남성 세 분이었는데\n\n손이 빠르고 호흡이 척척 맞아 보였습니다.\n\n다만\n\n내부가 상당히 좁은 편이라 식사 시간에는 대기가 불가피할 것 같습니다.\n\n혹시 방문할 계획이 있다면 점심·저녁 피크 시간을 피해 가는 게 좋겠습니다.\n\n테이블은 길게 일자형으로 배치되어 있어 혼밥하기에도 아주 편한 구조였습니다.\n\n추운 날씨 속에서도 따끈한 국물과 푸짐한 고기를 즐기며  \n걷고 기다린 시간이 전혀 아깝지 않았던 한 끼였습니다.\n\n함께한 사람과 나눈 대화\n\n그리고 마음까지 따뜻해진 맛이 오래 기억에 남을 것 같습니다.\n\n[anadasia88 님의 블로그](https://anadasia88.tistory.com)[소소한 일상 속에서 발견하는 작은 행복, 그리고 그 순간들을 기록하는 공간입니다.\n길 위에서 마주한 풍경, 잔잔한 음악이 흐르는 카페, 그리고 일상 속에서 찾은 특별한 순간들.\n이곳에서 나만의 감성을 담아 기록합니다.](https://anadasia88.tistory.com)\n\n댓글0\n\n---\n\n## 티스토리툴바\n\n## 개인정보\n\n* [티스토리 홈](https://www.tistory.com)\n* [포럼](https://www.tistory.com/forum)\n* [로그인](#)\n\n\n\n\n\n## 단축키\n\n### 내 블로그\n\n|  |  |\n| --- | --- |\n| 내 블로그 - 관리자 홈 전환 | `Q` |\n| 새 글 쓰기 | `W` |\n\n### 블로그 게시글\n\n|  |  |\n| --- | --- |\n| 글 수정 (권한 있는 경우) | `E` |\n| 댓글 영역으로 이동 | `C` |\n\n### 모든 영역\n\n|  |  |\n| --- | --- |\n| 이 페이지의 URL 복사 | `S` |\n| 맨 위로 이동 | `T` |\n| 티스토리 홈 이동 | `H` |\n| 단축키 안내 | `Shift` + `/`  `⇧` + `/` |\n\n\\* 단축키는 한글/영문 대소문자로 이용 가능하며, 티스토리 기본 도메인에서만 동작합니다.'},
#    {'url': 'https://www.siksinhot.com/theme/magazine/6607',
#     'title': '선유도역 맛집 점심·모임·회식에 좋은 곳 TOP 4 - 식신',
#     'content': "Q. 어떤 미역국을 많이 주문하나요?\n\nA. 소고기·얼큰 소고기, 전복·조개, 순살 가자미 등으로 선택폭이 넓습니다. 얼큰 계열은 해장에, 전복·가자미는 담백한 맛을 선호하는 분들께 반응이 좋습니다.\n\n위치: 서울 영등포구 양평로21가길 4, 1층 102·103호(선유도역 7번 출구 도보 약 5분)\n\n영업시간: 10:30~21:00, 라스트오더 20:20, 매주 일요일 휴무, 브레이크 14:30~16:30\n\n가격대: 주요 미역국 약 1.4만~1.7만원대(예: 얼큰 소고기 14,000원, 전복·조개 17,000원 등)\n\n메뉴: 소고기/얼큰 소고기/전복/조개/순살 가자미/황태 미역국, 가자미 흑임자샐러드·찹쌀 오징어튀김 등 사이드\n\n편의: 매장 앞 주차 소수(약 3~4대), 테이블 주문용 태블릿, 셀프 반찬 코너, 아기 의자 구비, 포장 가능\n\n특징: 완도산 100% 미역 사용, 진하게 우려낸 해산물 베이스의 국물로 식사 만족도 높음\n\n### 2. 샤브올데이 선유도역점 — 평일 점심 무한리필과 다양한 소스·월남쌈\n\n#### 자주 묻는 질문\n\nQ. 점심 가격과 이용 시간 제한은 어떻게 되나요?\n\nA. 평일 점심 성인 기준 24,900원으로 안내되며, 이용 시간은 80분 제한이 적용됩니다.\n\nQ. 주류와 음료 이용은 어떤가요?\n\nA. 탄산·주스·커피 등과 함께 생맥주도 셀프 바에서 무제한으로 이용할 수 있도록 운영됩니다.\n\n위치: 서울 영등포구 양평로25길 8(선유도역 인근)\n\n가격대: 평일 점심 무한리필 24,900원(성인), 시간 제한 80분 [...] #### 자주 묻는 질문\n\nQ. 주말 대기가 있나요? 예약은 가능한가요?\n\nA. 주말 점심 시간대에는 대기가 발생하는 편이지만 회전이 빠른 편입니다. 매장 안내에 따라 테이블 예약 시스템 이용이 가능합니다.\n\nQ. 처음 방문인데 어떤 조합이 무난할까요?\n\nA. 소프트 타코(치킨)와 치미창가를 함께 주문하거나, 단품보다 구성이 좋은 세트를 선택하면 효율적입니다.\n\n위치: 서울 영등포구 선유로51길 31, 1층(선유도역·선유도공원 인근)\n\n메뉴: 소프트/하드 타코(치킨·불고기 등 선택), 치미창가, 엔칠라다, 나초 등\n\n편의: 테이블 주문용 태블릿, 예약 시스템 운영, 포장 가능\n\n특징: 소스가 풍부한 치미창가와 담백한 소프트 타코 등 취향에 따라 선택 폭이 넓어 한강 피크닉용 포장도 수월\n\n## 비교 & 선택 팁\n\n1. 늦은 시간까지 모임·회식 → 호운양꼬치\n\n2. 속 편한 따뜻한 국물 점심 → 삼대미역 선유도 본점\n\n3. 가성비 무한리필과 월남쌈 → 샤브올데이 선유도역점\n\n4. 이국적 메뉴·포장 후 공원 피크닉 → 멕시코식당 선유도\n\n더 많은 '선유도역 맛집' 정보는 아래에서 확인하세요.\n\n### 호운양꼬치\n\n출처 : 호운양꼬치 인스타그램 검색 결과\n출처 : 식신 회원 '554689' 님의 리뷰 이미지\n출처 : 식신 회원 '554689' 님의 리뷰 이미지\n출처 : 식신 회원 '554689' 님의 리뷰 이미지\n출처 : 식신 회원 '554689' 님의 리뷰 이미지\n\n#### 메뉴 정보\n\n#### 별 인증 히스토리\n\n#### 맛집 근처 위치\n\n식당사진\n\n댓글\n\n식신\n블로그\n페이스북\n인스타그램 [...] 가격대: 평일 점심 무한리필 24,900원(성인), 시간 제한 80분\n\n메뉴: 시그니처 양지·얼큰 양지 2종 육수 선택, 소고기 부위 3종 무한, 각종 채소·버섯·면, 월남쌈 재료, 샐러드·후식 코너\n\n편의: 건물 지하 주차(셀프 등록 2시간), 창가석 포함 좌석 다수, 육수·반찬 셀프 운영\n\n특징: 소스 선택 폭이 넓어 취향 맞추기 쉬우며, 맥주 포함 셀프 바 구성으로 가성비 있게 즐기기 좋음\n\n### 3. 호운양꼬치 선유도점 — 회식·모임에 좋은 양꼬치와 중식 안주\n\n호운양꼬치\n\n호운양꼬치\n\n호운양꼬치 바로가기▶\n\n#### 자주 묻는 질문\n\nQ. 영업시간과 라스트오더는 어떻게 되나요?\n\nA. 12:00~24:00 운영하며 라스트오더는 23:20으로 안내됩니다.\n\nQ. 어떤 메뉴를 함께 주문하면 좋을까요?\n\nA. 양꼬치·양갈비살과 함께 꿔바로우, 가지 튀김, 향신료 볶음(예: 오징어 요리)을 곁들이면 구성 밸런스가 좋습니다.\n\n위치: 서울 영등포구 선유로47길 15, 구산드림타워\n\n영업시간: 12:00~24:00, 라스트오더 23:20, 전화 02-3667-3898\n\n메뉴: 양꼬치·양갈비살, 꿔바로우, 가지 튀김, 매콤 볶음류 등\n\n편의: 넓은 테이블 구성, 소스(쯔란·특제소스) 제공, 모임·회식 적합\n\n특징: 꼬치 그릴로 균일하게 익혀 초심자도 먹기 편하며, 안주류 선택지가 다양해 술자리 호응이 높음\n\n### 4. 멕시코식당 선유도 — 타코·치미창가로 즐기는 캐주얼 멕시칸\n\n#### 자주 묻는 질문\n\nQ. 주말 대기가 있나요? 예약은 가능한가요?",
#     'score': 0.9992735,
#     'raw_content': "![twinLogo_link](/static2/images/common/twinLogo_pc.png)\n\n신고하기\n\n신고 사유 (필수)\n\n신고 접수\n\n# 선유도역 맛집 점심·모임·회식에 좋은 TOP 4\n\n![](https://img.siksinhot.com/seeon/1764653961338229.webp)\n![공유하기](/static2/images/common/bg_icon_share.png)\n![카카오스토리](/static2/images/common/btn_s_kas.png)\n![페이스북](/static2/images/common/btn_s_facebook.png)\n![밴드](/static2/images/common/btn_s_band.png)\n![URL 복사](/static2/images/common/btn_s_url.png)\n\n## **'선유도역 맛집' 공통 FAQ**\n\n**Q. 주말 웨이팅을 줄이려면 언제 가면 좋을까요?**\n\n**A.** 주말 점심·저녁 피크에는 대기가 잦습니다. 평일 또는 오픈 직후 방문을 권하고, 일부 매장(예: 멕시코식당)은 사전 예약 시스템을 운영해 대기 시간을 단축할 수 있습니다.\n\n**Q. 선유도역 주변 주차는 가능한가요?**\n\n**A.** 매장별로 상이합니다. 샤브올데이는 건물 지하 주차(셀프 등록 2시간) 이용이 가능하고, 삼대미역은 매장 앞 소수 주차가 가능합니다. 방문 전 매장별 주차 가능 여부를 확인하세요.\n\n**Q. 가족 모임이나 회식에 적합한 곳이 있을까요?**\n\n**A.** 단체라면 테이블 간격이 넓고 늦게까지 운영하는 호운양꼬치가 편하며, 아이 동반 가족은 아기 의자와 셀프 반찬 코너가 갖춰진 삼대미역이 무난합니다. 무한 리필로 다양하게 즐기려면 샤브올데이가 좋습니다.\n\n선유도역 도보권에서 검증된 후기 위주로 점심, 가족·단체 모임, 회식까지 활용도 높은 4곳을 엄선했습니다. 위치·영업시간·메뉴·편의 정보를 중심으로 실사용 팁과 함께 비교할 수 있도록 정리했습니다.\n\n### 1. 삼대미역 선유도 본점 — 완도산 미역으로 끓인 진한 미역국 전문\n\n#### **자주 묻는 질문**\n\n**Q. 영업시간과 휴무, 브레이크 타임이 궁금해요.**\n\n**A.** 오전 10:30 오픈, 라스트오더 20:20이며 매주 일요일은 쉽니다. 브레이크 타임은 14:30~16:30로 안내되어 있습니다.\n\n**Q. 어떤 미역국을 많이 주문하나요?**\n\n**A.** 소고기·얼큰 소고기, 전복·조개, 순살 가자미 등으로 선택폭이 넓습니다. 얼큰 계열은 해장에, 전복·가자미는 담백한 맛을 선호하는 분들께 반응이 좋습니다.\n\n**위치:** 서울 영등포구 양평로21가길 4, 1층 102·103호(선유도역 7번 출구 도보 약 5분)\n\n**영업시간:** 10:30~21:00, 라스트오더 20:20, 매주 일요일 휴무, 브레이크 14:30~16:30\n\n**가격대:** 주요 미역국 약 1.4만~1.7만원대(예: 얼큰 소고기 14,000원, 전복·조개 17,000원 등)\n\n**메뉴:** 소고기/얼큰 소고기/전복/조개/순살 가자미/황태 미역국, 가자미 흑임자샐러드·찹쌀 오징어튀김 등 사이드\n\n**편의:** 매장 앞 주차 소수(약 3~4대), 테이블 주문용 태블릿, 셀프 반찬 코너, 아기 의자 구비, 포장 가능\n\n**특징:** 완도산 100% 미역 사용, 진하게 우려낸 해산물 베이스의 국물로 식사 만족도 높음\n\n### 2. 샤브올데이 선유도역점 — 평일 점심 무한리필과 다양한 소스·월남쌈\n\n#### **자주 묻는 질문**\n\n**Q. 점심 가격과 이용 시간 제한은 어떻게 되나요?**\n\n**A.** 평일 점심 성인 기준 24,900원으로 안내되며, 이용 시간은 80분 제한이 적용됩니다.\n\n**Q. 주류와 음료 이용은 어떤가요?**\n\n**A.** 탄산·주스·커피 등과 함께 생맥주도 셀프 바에서 무제한으로 이용할 수 있도록 운영됩니다.\n\n**위치:** 서울 영등포구 양평로25길 8(선유도역 인근)\n\n**가격대:** 평일 점심 무한리필 24,900원(성인), 시간 제한 80분\n\n**메뉴:** 시그니처 양지·얼큰 양지 2종 육수 선택, 소고기 부위 3종 무한, 각종 채소·버섯·면, 월남쌈 재료, 샐러드·후식 코너\n\n**편의:** 건물 지하 주차(셀프 등록 2시간), 창가석 포함 좌석 다수, 육수·반찬 셀프 운영\n\n**특징:** 소스 선택 폭이 넓어 취향 맞추기 쉬우며, 맥주 포함 셀프 바 구성으로 가성비 있게 즐기기 좋음\n\n### 3. 호운양꼬치 선유도점 — 회식·모임에 좋은 양꼬치와 중식 안주\n\n![호운양꼬치](https://img.siksinhot.com/place/1554775351240097.jpg)\n\n![호운양꼬치](https://img.siksinhot.com/place/1554775351240097.jpg)\n\n[호운양꼬치 바로가기▶](https://www.siksinhot.com/P/840999)\n\n#### **자주 묻는 질문**\n\n**Q. 영업시간과 라스트오더는 어떻게 되나요?**\n\n**A.** 12:00~24:00 운영하며 라스트오더는 23:20으로 안내됩니다.\n\n**Q. 어떤 메뉴를 함께 주문하면 좋을까요?**\n\n**A.** 양꼬치·양갈비살과 함께 꿔바로우, 가지 튀김, 향신료 볶음(예: 오징어 요리)을 곁들이면 구성 밸런스가 좋습니다.\n\n**위치:** 서울 영등포구 선유로47길 15, 구산드림타워\n\n**영업시간:** 12:00~24:00, 라스트오더 23:20, 전화 02-3667-3898\n\n**메뉴:** 양꼬치·양갈비살, 꿔바로우, 가지 튀김, 매콤 볶음류 등\n\n**편의:** 넓은 테이블 구성, 소스(쯔란·특제소스) 제공, 모임·회식 적합\n\n**특징:** 꼬치 그릴로 균일하게 익혀 초심자도 먹기 편하며, 안주류 선택지가 다양해 술자리 호응이 높음\n\n### 4. 멕시코식당 선유도 — 타코·치미창가로 즐기는 캐주얼 멕시칸\n\n#### **자주 묻는 질문**\n\n**Q. 주말 대기가 있나요? 예약은 가능한가요?**\n\n**A.** 주말 점심 시간대에는 대기가 발생하는 편이지만 회전이 빠른 편입니다. 매장 안내에 따라 테이블 예약 시스템 이용이 가능합니다.\n\n**Q. 처음 방문인데 어떤 조합이 무난할까요?**\n\n**A.** 소프트 타코(치킨)와 치미창가를 함께 주문하거나, 단품보다 구성이 좋은 세트를 선택하면 효율적입니다.\n\n**위치:** 서울 영등포구 선유로51길 31, 1층(선유도역·선유도공원 인근)\n\n**메뉴:** 소프트/하드 타코(치킨·불고기 등 선택), 치미창가, 엔칠라다, 나초 등\n\n**편의:** 테이블 주문용 태블릿, 예약 시스템 운영, 포장 가능\n\n**특징:** 소스가 풍부한 치미창가와 담백한 소프트 타코 등 취향에 따라 선택 폭이 넓어 한강 피크닉용 포장도 수월\n\n## **비교 & 선택 팁**\n\n**1. 늦은 시간까지 모임·회식** → 호운양꼬치\n\n**2. 속 편한 따뜻한 국물 점심** → 삼대미역 선유도 본점\n\n**3. 가성비 무한리필과 월남쌈** → 샤브올데이 선유도역점\n\n**4. 이국적 메뉴·포장 후 공원 피크닉** → 멕시코식당 선유도\n\n더 많은 '선유도역 맛집' 정보는 아래에서 확인하세요.\n\n### [호운양꼬치](https://www.siksinhot.com/P/840999)\n\n![출처 : 호운양꼬치 인스타그램 검색 결과](https://img.siksinhot.com/place/1554775351240097.jpg?c=Y&w=1480&h=920)\n![출처 : 식신 회원 '554689' 님의 리뷰 이미지](https://img.siksinhot.com/story/1554553172131014.jpeg?c=Y&w=1480&h=920)\n![출처 : 식신 회원 '554689' 님의 리뷰 이미지](https://img.siksinhot.com/story/1554553173354009.jpeg?c=Y&w=1480&h=92 ...
#    {'url': 'https://blog.naver.com/myul/223259807937',
#     'title': '[선유도역 맛집 리스트/선유도 맛집 비교 top3] 또순이네집, 너도나도 ...',
#     'content': '<ul style="display: none;">\n<li> <span style="background-image:none;"></span> <span style="display: inline;">공감</span> <span style="display: inline;">0</span>  </li>\n<li> <span style="background-image:none;"></span> <span style="display: inline;">칭찬</span> <span style="display: inline;">0</span>  </li>\n<li> <span style="background-image:none;"></span> <span style="display: inline;">감사</span> <span style="display: inline;">0</span>  </li>\n<li> <span style="background-image:none;"></span> <span style="display: inline;">웃김</span> <span style="display: inline;">0</span>  </li>\n<li> <span style="background-image:none;"></span> <span style="display: inline;">놀람</span> <span style="display: inline;">0</span>  </li> [...] <ul style="display: none;">\n<li> <span style="background-image:none;"></span> <span style="display: inline;">공감</span> <span style="display: inline;">0</span>  </li>\n<li> <span style="background-image:none;"></span> <span style="display: inline;">칭찬</span> <span style="display: inline;">0</span>  </li>\n<li> <span style="background-image:none;"></span> <span style="display: inline;">감사</span> <span style="display: inline;">0</span>  </li>\n<li> <span style="background-image:none;"></span> <span style="display: inline;">웃김</span> <span style="display: inline;">0</span>  </li>\n<li> <span style="background-image:none;"></span> <span style="display: inline;">놀람</span> <span style="display: inline;">0</span>  </li> [...] <meta content="네이버 블로그 | 앵겔지수 0.5" property="og:article:author"></meta> <meta content="네이버 블로그 | 앵겔지수 0.5" property="og:site\\_name"></meta> <meta content="정대리" property="naverblog:nickname"></meta> <meta content=" property="naverblog:profile\\_image"></meta> <meta content=""[선유도역 맛집 리스트/선유도 맛집 비교 top3] 또순이네집, 너도나도식당, 전주집, 느티나무쌈밥, 강강술래 feat. 한식편": property="me2:post\\_body"></meta> <meta content="네이버블로그 앵겔지수 0.5" property="me2:post\\_tag"></meta> <meta content="blog" property="me:feed:serviceId"></meta> <title>[선유도역 맛집 리스트/선유도 맛집 비교 top3] 또순이네집, 너도나도식당, 전주집, 느티나무쌈밥, 강강술래 feat. 한식편 : 네이버 블로그</title> <link href=" <link href=" </head>',
#     'score': 0.99913067,
#     'raw_content': '         앵겔지수 0.5 : 네이버 블로그 \n<html>\n<head><meta content="no-cache" http-equiv="Pragma"></meta> <meta content="-1" http-equiv="Expires"></meta> <meta content="always" name="referrer"></meta> <link href="https://ssl.pstatic.net/t.static.blog/mylog/versioning/LayoutTopCommon-250287196\\_https.css"></link> <link href="https://ssl.pstatic.net/t.static.blog/mylog/versioning//common/css/music/player-d3fc09e\\_https.css"></link> <link href="https://ssl.pstatic.net/static/blog/icon/favicon.ico"></link> <meta content="[선유도역 맛집 리스트/선유도 맛집 비교 top3] 또순이네집, 너도나도식당, 전주집, 느티나무쌈밥, 강강술래 feat. 한식편" property="og:title"></meta> <meta content="https://blogthumb.pstatic.net/MjAyMzExMDlfMTAw/MDAxNjk5NDg0MTQ2NjMy.ZPOkplIfoeRmrFFf6k1pl8mGkb7p\\_li\\_L4wl8V6C7Swg.axdvCF8Jdmf9VH1x8H6d2Rxkeg1e1QCuPfEsUWItgcEg.JPEG.myul/20230504%A3%DF200202.jpg?type=w2" property="og:image"></meta> <meta content="---내 돈 주고 내가 사 먹은 내돈내산 후기--- [선유도역 맛집 리스트/선유도 맛집 비교 top3] 또순이네집,..." property="og:description"></meta> <meta content="https://blog.naver.com/myul/223259807937" property="og:url"></meta> <meta content="blog" property="me:feed:serviceId"></meta> <meta content="index,follow" name="robots"></meta> <meta content="text/html;charset=UTF-8" http-equiv="Content-Type"></meta> <meta content="article" property="og:type"></meta> <meta content="네이버 블로그 | 앵겔지수 0.5" property="og:article:author"></meta> <meta content="네이버 블로그 | 앵겔지수 0.5" property="og:site\\_name"></meta> <meta content="정대리" property="naverblog:nickname"></meta> <meta content="https://blogpfthumb-phinf.pstatic.net/20140708\\_156/myul\\_1404774889957gcKW1\\_JPEG/1387460121211.jpg" property="naverblog:profile\\_image"></meta> <meta content=""[선유도역 맛집 리스트/선유도 맛집 비교 top3] 또순이네집, 너도나도식당, 전주집, 느티나무쌈밥, 강강술래 feat. 한식편":https://blog.naver.com/myul/223259807937" property="me2:post\\_body"></meta> <meta content="네이버블로그 앵겔지수 0.5" property="me2:post\\_tag"></meta> <meta content="blog" property="me:feed:serviceId"></meta> <title>[선유도역 맛집 리스트/선유도 맛집 비교 top3] 또순이네집, 너도나도식당, 전주집, 느티나무쌈밥, 강강술래 feat. 한식편 : 네이버 블로그</title> <link href="https://ssl.pstatic.net/t.static.blog/mylog/versioning/PostView-876979288\\_https.css"></link> <link href="https://editor-static.pstatic.net/v/basic/1.74.0/css/se.viewer.desktop.css?v=1.74.0-20260206160348"></link> </head>\n<body>\n<div>\n<div>\n<div><a href="http://www.naver.com">NAVER</a> <a href="https://blog.naver.com">블로그</a> </div>\n<div><a href="https://blog.naver.com/PostList.naver?blogId=myul"> <strong>앵겔지수 0.5</strong> </a> </div>\n<div>\n<form><fieldset> <legend>블로그 검색</legend>\n<div><input title="이 블로그에서 검색"></input> <label>이 블로그에서 검색</label>\n<div style="display: none">\n<ul></ul> </div> <input></input> <a href="#"></a> </div> </fieldset> </form> </div>\n<div><a href="#"> <span> </span> </a> </div> </div> </div>\n<div></div>\n<div></div>\n<div>\n<div>\n<div style="z-index: 1001">\n<div>\n<div>\n<div>\n<div><a href="#"> <span> <span></span> </span> <span></span> <span></span> </a>\n<ul style="display: none;">\n<li><a href="#ratingbutton-like"> <span style="background-image:none;"></span> <span style="display: inline;">공감</span> <span style="display: inline;">0</span> </a> </li>\n<li><a href="#ratingbutton-impressive"> <span style="background-image:none;"></span> <span style="display: inline;">칭찬</span> <span style="display: inline;">0</span> </a> </li>\n<li><a href="#ratingbutton-thanks"> <span style="background-image:none;"></span> <span style="display: inline;">감사</span> <span style="display: inline;">0</span> </a> </li>\n<li><a href="#ratingbutton-haha"> <span style="background-image:none;"></span> <span style="display: inline;">웃김</span> <span style="display: inline;">0</span> </a> </li>\n<li><a href="#ratingbutton-wow"> <span style="background-image:none;"></span> <span style="display: inline;">놀람</span> <span style="display: inline;">0</span> </a> </li>\n<li><a href="#ratingbutton-sad"> <span style="background-image:none;"></span> <span style="display: inline;">슬픔</ ...
#   'response_time': 5.42,
#   'request_id': '75e94928-4f52-4846-a697-5c0565120ac0'},
#  'answer': '선유도역 주변의 추천 맛집으로는 또순이네 쌀국수, 샤브올데이(무한리필), 호운양꼬치, 멕시코식당 타코가 있습니다. 이들 가게는 각각 다양한 메뉴를 제공하며, 특히 또순이네는 된장찌개로 유명합니다. 각 식당은 접근성이 좋고, 다양한 스타일의 음식을 즐길 수 있는 장소입니다.'}

# %% [markdown]
# - 결론 : web search를 위한 rewrite는 굳이 필요없다.
#     - 서비스 관점에서 꼭 필요한건지 고민해보고, rewrite를 하는 것도 LLM 호출하는 것이기 때문에 비용과 시간이 든다.
